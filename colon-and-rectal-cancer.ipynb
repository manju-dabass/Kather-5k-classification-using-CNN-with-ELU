# %%
## Import libraries

import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix,classification_report
# Out:
# Using TensorFlow backend.

# %%
## I use 64x64 grayscale images represented into a CSV

data = pd.read_csv("../input/hmnist_64_64_L.csv")

# %%
## Let's look the data

data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  ...    pixel4094  pixel4095  label
# 0        134         99        119  ...          140        195      2
# 1         55         64         74  ...           68         69      2
# 2        114        116        136  ...           89        122      2
# 3         86         82         88  ...           63         48      2
# 4        168        143        140  ...          158        149      2
#
# [5 rows x 4097 columns]

# %%
## Let's look the shape

data.shape
# Out:
# (5000, 4097)

# %%
# Splitting labels and features

Y = data["label"]
data.drop(["label"],axis=1, inplace=True)
X = data

# %%
# And creating a countplot

plt.figure(figsize=(15,7))
g = sns.countplot(Y, palette="winter_r")
plt.suptitle("Amount of each classes")
plt.show()

# %%
## The dataset is well balanced (probably perfect)

Y.value_counts()
# Out:
# 7    625
# 3    625
# 6    625
# 2    625
# 5    625
# 1    625
# 8    625
# 4    625
# Name: label, dtype: int64

# %%
## Manual scaling

X = X / 255.0

# %%
## Looking for an example image

img = X.iloc[75].as_matrix()
img = img.reshape(64,64)
plt.imshow(img)
plt.suptitle("An example of image on the dataset")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
## Reshaping images for the CNN

X = X.values.reshape(-1,64,64,1)     
Y = Y.values

# %%
## Label Encoding into One-Hot

from keras.utils.np_utils import to_categorical 
Y = to_categorical(Y)

# %%
## Train and test splitting

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

# %%
## Printing shapes

print("X_train.shape: ",X_train.shape)
print("X_test.shape: ",X_test.shape)
print("y_train.shape: ",y_train.shape)
print("y_test.shape: ",y_test.shape)
# Out:
# X_train.shape:  (4000, 64, 64, 1)
# X_test.shape:  (1000, 64, 64, 1)
# y_train.shape:  (4000, 9)
# y_test.shape:  (1000, 9)

# %% [markdown]
# <h1> CNN CREATION

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(filters = 128, kernel_size = (5,5),padding = 'same',activation ='relu', input_shape = (64,64,1)))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(filters = 64, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(filters = 64, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(256,activation = "elu"))          
model.add(tf.keras.layers.Dense(64,activation = "elu"))
model.add(tf.keras.layers.Dense(32,activation = "elu"))

model.add(tf.keras.layers.Dense(9, activation = "softmax"))

# %%
## Let's print the summary of the model

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 128)       3328
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1048832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 9)                 297
# =================================================================
# Total params: 1,181,705
# Trainable params: 1,181,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
## And compile it

model.compile(optimizer = "Adam" , loss = "binary_crossentropy", metrics=["accuracy"])

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=0.5, 
        zoom_range = 0.5, 
        width_shift_range=0.5,  
        height_shift_range=0.5, 
        horizontal_flip=True, 
        vertical_flip=True)

datagen.fit(X_train)

# %%
## Model training

EPOCHS = 50
BATCH_SIZE = 32


hist = model.fit_generator(datagen.flow(X_train,y_train, batch_size=BATCH_SIZE),
                              epochs = EPOCHS, validation_data = (X_test,y_test))
# Out:
# Epoch 1/50
# 125/125 [==============================] - 9s 75ms/step - loss: 0.2651 - acc: 0.8897 - val_loss: 0.2569 - val_acc: 0.8950
# Epoch 2/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2151 - acc: 0.8982 - val_loss: 0.2123 - val_acc: 0.9077
# Epoch 3/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2009 - acc: 0.9073 - val_loss: 0.2523 - val_acc: 0.8969
# Epoch 4/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1935 - acc: 0.9107 - val_loss: 0.2099 - val_acc: 0.9003
# Epoch 5/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1860 - acc: 0.9136 - val_loss: 0.1981 - val_acc: 0.9044
# Epoch 6/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1819 - acc: 0.9161 - val_loss: 0.3009 - val_acc: 0.8811
# Epoch 7/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1818 - acc: 0.9163 - val_loss: 0.2778 - val_acc: 0.8790
# Epoch 8/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1803 - acc: 0.9165 - val_loss: 0.2189 - val_acc: 0.8991
# Epoch 9/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1751 - acc: 0.9181 - val_loss: 0.1982 - val_acc: 0.9142
# Epoch 10/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1688 - acc: 0.9239 - val_loss: 0.2835 - val_acc: 0.8841
# Epoch 11/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1675 - acc: 0.9248 - val_loss: 0.1945 - val_acc: 0.9087
# Epoch 12/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1655 - acc: 0.9245 - val_loss: 0.1773 - val_acc: 0.9302
# Epoch 13/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1625 - acc: 0.9269 - val_loss: 0.2083 - val_acc: 0.9096
# Epoch 14/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1622 - acc: 0.9281 - val_loss: 0.2260 - val_acc: 0.9017
# Epoch 15/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1677 - acc: 0.9234 - val_loss: 0.2309 - val_acc: 0.8993
# Epoch 16/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1602 - acc: 0.9276 - val_loss: 0.1740 - val_acc: 0.9131
# Epoch 17/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1596 - acc: 0.9286 - val_loss: 0.1996 - val_acc: 0.9022
# Epoch 18/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1558 - acc: 0.9300 - val_loss: 0.1670 - val_acc: 0.9129
# Epoch 19/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1579 - acc: 0.9293 - val_loss: 0.1668 - val_acc: 0.9137
# Epoch 20/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1562 - acc: 0.9295 - val_loss: 0.1581 - val_acc: 0.9360
# Epoch 21/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1545 - acc: 0.9307 - val_loss: 0.1627 - val_acc: 0.9344
# Epoch 22/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1502 - acc: 0.9357 - val_loss: 0.1650 - val_acc: 0.9147
# Epoch 23/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1481 - acc: 0.9357 - val_loss: 0.2029 - val_acc: 0.9120
# Epoch 24/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1501 - acc: 0.9365 - val_loss: 0.1745 - val_acc: 0.9252
# Epoch 25/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1505 - acc: 0.9354 - val_loss: 0.1207 - val_acc: 0.9520
# Epoch 26/50
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1503 - acc: 0.9348 - val_loss: 0.1960 - val_acc: 0.9149
# Epoch 27/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1394 - acc: 0.9399 - val_loss: 0.1253 - val_acc: 0.9481
# Epoch 28/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1412 - acc: 0.9405 - val_loss: 0.1163 - val_acc: 0.9547
# Epoch 29/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1403 - acc: 0.9407 - val_loss: 0.1132 - val_acc: 0.9542
# Epoch 30/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1353 - acc: 0.9419 - val_loss: 0.1490 - val_acc: 0.9372
# Epoch 31/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1339 - acc: 0.9434 - val_loss: 0.1084 - val_acc: 0.9541
# Epoch 32/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1378 - acc: 0.9426 - val_loss: 0.1393 - val_acc: 0.9462
# Epoch 33/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1393 - acc: 0.9401 - val_loss: 0.1041 - val_acc: 0.9589
# Epoch 34/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1410 - acc: 0.9396 - val_loss: 0.1338 - val_acc: 0.9476
# Epoch 35/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1327 - acc: 0.9445 - val_loss: 0.1646 - val_acc: 0.9364
# Epoch 36/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1425 - acc: 0.9415 - val_loss: 0.1052 - val_acc: 0.9586
# Epoch 37/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1294 - acc: 0.9452 - val_loss: 0.1340 - val_acc: 0.9470
# Epoch 38/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1326 - acc: 0.9433 - val_loss: 0.1258 - val_acc: 0.9492
# Epoch 39/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1335 - acc: 0.9449 - val_loss: 0.1186 - val_acc: 0.9506
# Epoch 40/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1352 - acc: 0.9428 - val_loss: 0.1262 - val_acc: 0.9479
# Epoch 41/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1295 - acc: 0.9452 - val_loss: 0.1549 - val_acc: 0.9398
# Epoch 42/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1272 - acc: 0.9470 - val_loss: 0.1077 - val_acc: 0.9560
# Epoch 43/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1308 - acc: 0.9450 - val_loss: 0.1473 - val_acc: 0.9411
# Epoch 44/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1263 - acc: 0.9469 - val_loss: 0.1377 - val_acc: 0.9430
# Epoch 45/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1295 - acc: 0.9444 - val_loss: 0.1076 - val_acc: 0.9567
# Epoch 46/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1294 - acc: 0.9451 - val_loss: 0.1030 - val_acc: 0.9606
# Epoch 47/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1292 - acc: 0.9455 - val_loss: 0.1541 - val_acc: 0.9396
# Epoch 48/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1323 - acc: 0.9437 - val_loss: 0.1533 - val_acc: 0.9368
# Epoch 49/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1263 - acc: 0.9468 - val_loss: 0.1262 - val_acc: 0.9496
# Epoch 50/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1273 - acc: 0.9472 - val_loss: 0.1785 - val_acc: 0.9324

# %%
#à Predict the values from the validation dataset
y_pred = model.predict(X_test)


## Convert predictions classes to one hot vectors 
y_pred_classes = np.argmax(y_pred,axis = 1) 


## Convert validation observations to one hot vectors
y_true = np.argmax(y_test,axis = 1) 


## Compute the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes) 

## Compute loss and accuracy
test_loss, test_accuracy = model.evaluate(X_test,  y_test, verbose=2)

# %%
## Plot the confusion matrix

f,ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="summer_r", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
## Print accuracy and loss

print(f"Accuracy: {test_accuracy}\nLoss: {test_loss}")
# Out:
# Accuracy: 0.9324444341659546
# Loss: 0.1785411033630371
